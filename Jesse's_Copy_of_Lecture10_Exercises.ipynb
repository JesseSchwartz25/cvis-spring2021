# %% [markdown]
# <a href="https://colab.research.google.com/github/JesseSchwartz25/cvis-spring2021/blob/main/Jesse's_Copy_of_Lecture10_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Lecture 10 Take-home Exercises.  Discussion is allowed.
# Due: March 3, 2021.

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import fftpack
import imageio
import scipy

# %% [markdown]
# Exericse 0 Basic Image FFT.

# %%
random_img = np.random.random((256,256))
Z = np.random.random((256,256))   # Test data

# %%
# compute the FFT, finish the code below 
f = np.fft.fft2(random_img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 30*np.log(np.abs(fshift))

# %%
# display the original image and FFT
plt.subplot(121),plt.imshow(random_img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Log Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# diagonal image
diag_img = 100*np.identity(255)
#To do compute the FFT
f = np.fft.fft2(diag_img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 30*np.log(np.abs(fshift))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log

# %%
# display the original image and FFT
plt.subplot(121),plt.imshow(diag_img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Log Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ## Exercise 1 Can you manipulate the fourier spectrum and remiove low-frequenty of the image. Can you modify it to remove high frequnecy?

# %%
img = imageio.imread('imageio:astronaut.png',as_gray=True)
plt.figure()
plt.imshow(img, cmap='gray')

# %%
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 30*np.log(np.abs(fshift))

plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
plt.title('Log Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# To do. How do you remove the high frequencies Display the DFT magnitutde and the resulting image here
#mask the outside, keep the inside
#check slides to learn more (lec 9 & 10)

f_high = f.copy()

# f_high[50:-50 , 50:-50] = 1
f_high[30:-30] = 1
f_high[:, 30:-30] = 1
# f_high[-50:, -50:] = 1



fshifthigh = np.fft.fftshift(f_high)

highMagSpec = 30*np.log(np.abs(fshifthigh))

f_ishift = np.fft.ifftshift(fshifthigh)
img_backhigh = np.fft.ifft2(f_ishift)
img_backhigh = np.abs(img_backhigh)


plt.subplot(2,2,1)
plt.imshow(highMagSpec, cmap = 'gray')
plt.title("low pass filter - fourier")
plt.subplot(2,2,2)
plt.imshow(img_backhigh, cmap= 'gray')
plt.title("low pass filter - img")


# To do. how do you remove the low frequency?  Display the DFT magnitutde and the resulting image here
#cut a hole around the middle of the magnitude array, mask the inside keep the outside.

f_low = f.copy();
f_low[0:40, 0:40] = 1;
f_low[-40:, 0:40] = 1;
f_low[-40:, -40:] = 1;
f_low[0:40, -40:] = 1;




fshiftlow = np.fft.fftshift(f_low)

lowMagSpec = 30*np.log(np.abs(fshiftlow))

f_ishift = np.fft.ifftshift(fshiftlow)
img_back = np.fft.ifft2(f_ishift)
img_back = np.abs(img_back)


plt.subplot(2,2,3)
plt.imshow(lowMagSpec, cmap = 'gray')
plt.title("high pass filter - fourier")
plt.subplot(2,2,4)
plt.imshow(img_back, cmap= 'gray')
plt.title("high pass filter - img")


# f_ishift = np.fft.ifftshift(fshift)
# img_back = np.fft.ifft2(f_ishift)
# img_back = np.abs(img_back)

# use this eventually

plt.figure()
plt.subplot(1,1,1)
plt.imshow(img, cmap='gray')
plt.title("original")
# Out:
# Text(0.5, 1.0, 'original')

# %% [markdown]
# ## Exercise 2. Swich Phase and Magnitude.  read in the Cheetah and Zebra image.
# DFT both iuamges in Fourier domain and compute magnitude and phase.
# YOu can compute phase and magnitude as this:
# magnitude_zebra = 30*np.log(np.abs(fshit)
# phase_zabera = np.angle(fshift)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Todo  read in cheeta and zebra images
# FFT cheeta image 
# compute magnitude
import cv2

img = imageio.imread("/content/drive/MyDrive/Colab Notebooks/cheetah.png", as_gray=True)
# scipy.misc.imresize(img, [400,400])
img = cv2.resize(img, dsize=(400,400))

# img = np.resize(img, [400,400])
# im_blur = ndimage.filters.gaussian_filter (img, 7)
# img = im_blur[::2, ::2];


f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
# compute magnitude
# magnitude_cheetah = 30*np.log(np.abs(fshift))
magnitude_cheetah = np.abs(fshift)
# compute phase
phase_cheetah = np.angle(fshift)





# Todo: repeat above with Zebra 

img2 = imageio.imread("/content/drive/MyDrive/Colab Notebooks/zebra.png", as_gray=True)

f2 = np.fft.fft2(img2)
fshift2 = np.fft.fftshift(f2)
# compute magnitude
# magnitude_zebra = 30*np.log(np.abs(fshift2))
magnitude_zebra = np.abs(fshift2)
# compute phase
phase_zebra = np.angle(fshift2)







# Todo: Display the original image and the DFT components
plt.figure()
plt.subplot(1,3,1)
plt.imshow(img, cmap='gray')
plt.title("Cheetah")

plt.subplot(1,3,2)
plt.imshow(np.log(magnitude_cheetah), cmap='gray')
plt.title("Cheetah mag spec")

plt.subplot(1,3,3)
plt.imshow(phase_cheetah, cmap='gray')
plt.title("Cheetah phase")

plt.figure()
plt.subplot(1,3,1)
plt.imshow(img2, cmap='gray')
plt.title("Zebra")

plt.subplot(1,3,2)
plt.imshow(np.log(magnitude_zebra), cmap='gray')
plt.title("Zebra mag spec")

plt.subplot(1,3,3)
plt.imshow(phase_zebra, cmap='gray')
plt.title("Zebra phase")



# Todo: Please reconstruct the images, please switch phase of zebra and cheeta, and display the final image here

# cmagzphase = 
# zmagcphase = 
# phase_zebra_padded = np.pad(phase_zebra, 192, mode='edge' )
# phase_zebra_padded = np.pad(phase_zebra_padded, [(0,0), (5,5)], mode='edge' )
# theta = np.cos(phase_zebra_padded)
# re = magnitude_cheetah*theta



re = magnitude_cheetah*np.cos(phase_zebra)
im = magnitude_cheetah*np.sin(phase_zebra)
Fcz = re+1j*im

f_ishift = np.fft.ifftshift(Fcz)
img_back = np.fft.ifft2(f_ishift)
img_back = np.abs(img_back)

plt.figure()
plt.imshow(img_back, cmap='gray')
plt.title("Cheetah mag with Zebra phase")




re = magnitude_zebra*np.cos(phase_cheetah)
im = magnitude_zebra*np.sin(phase_cheetah)
Fzc = (re+1j*im)

f_ishift = np.fft.ifftshift(Fzc)
img_back = np.fft.ifft2(f_ishift)
img_back = np.abs(img_back)

plt.figure()
plt.imshow(img_back, cmap='gray')
plt.title("Zebra mag with Cheetah phase")
# Out:
# Text(0.5, 1.0, 'Zebra mag with Cheetah phase')

# %% [markdown]
# # Exercise 3: Simple Image De-nosing
#  Read in the provided image moonlanding.png, which is heavily contaiinated with periorid noise. In this exercise, we aim to clean up the noise using FFT.
#  1. load the image with your favourite lib.
#  2. Use the 2DFFT in numpy.fft and plot the spectrum
#  3. The specdtrum consists of high and low frequency components. The noise is contained in the high frequency part of the spectrum. So set some of those components to zero.
#  4. Apply the inverse FFT to see the resulting image.

# %%
img3 = imageio.imread("/content/drive/MyDrive/Colab Notebooks/moonlanding.png", as_gray=True)

f3 = np.fft.fft2(img3)
fshift3 = np.fft.fftshift(f3)
magnitude_spectrum3 = 30*np.log(np.abs(fshift3))

plt.figure()
plt.imshow(magnitude_spectrum3, cmap='gray')

plt.figure()
plt.imshow(img3, cmap='gray')


#filtering out high frequencies
f3[40:-40] = 1
f3[:, 40:-40] = 1




f3 = np.fft.fftshift(f3)

highMagSpec3 = 30*np.log(np.abs(f3))

f_ishift3 = np.fft.ifftshift(f3)
img_back3 = np.fft.ifft2(f_ishift3)
img_back3 = np.abs(img_back3)


plt.figure()
plt.imshow(img_back3, cmap='gray')

plt.figure()
plt.imshow(highMagSpec3, cmap='gray')

# %% [markdown]
# ## Exercise 4: Filtering in FFT.  Build a Gaussian filter. Then show you can FFT the filter and the signal, multiply them together to low-pass the original image.

# %%
img = imageio.imread('imageio:astronaut.png',as_gray=True)
plt.figure()
plt.imshow(img, cmap='gray')
# image size, square side length, number of squares
ncols, nrows = img.shape

# %%
# FFT the original image
ftimage = np.fft.fft2(img)
ftimage = np.fft.fftshift(ftimage)
plt.imshow(np.log(np.abs(ftimage)),cmap='gray')
plt.show()

# %%
# Build and apply a Gaussian filter and make sure the size is correct
sigmax, sigmay = 30, 30
cy, cx = nrows/2, ncols/2
x = np.linspace(0, nrows, nrows)
y = np.linspace(0, ncols, ncols)
X, Y = np.meshgrid(x, y)
plt.imshow(X,cmap='gray')
plt.show()

plt.imshow(Y,cmap='gray')
plt.show()

# %%
gmask = np.exp(-(((X-cx)/sigmax)**2 + ((Y-cy)/sigmay)**2))


plt.imshow(gmask,cmap='gray')
plt.show()

# %%
# TODO: filtering in Fourier Domain

filtered = ftimage * gmask


# TDDo : # Finally, take the inverse transform and show the blurred image

f_ishift = np.fft.ifftshift(filtered)
img_back = np.fft.ifft2(f_ishift)
img_back = np.abs(img_back)



# plt.figure()
# plt.imshow(ftimage)

plt.figure()
plt.imshow(img_back, cmap='gray')

# %% [markdown]
# ## Exercise 5, how do you highpass filter the image in FFT domain?
# ## step one: create a high pass filter in FD and then perform convolution in FD?
# # Hint: many ways to create high pass filter 1) sobel, 2) subtract from low-pass
# # 3) or something like this:
# #kernel = np.array([[-1, -1, -1],
#  #                  [-1,  8, -1],
#   #                 [-1, -1, -1]])

# %%
# TOdo: use the above image example, finish the high-passing 

from scipy import ndimage

# high_passed = np.convolve(ftimage, np.array([[-1, -1, -1], [-1, 8, -1], [-1, -1, -1]]))
# ftimage_magspec = np.log(np.abs(ftimage))
ftimage_magspec = np.abs(ftimage)
gmask_high = gmask *-1
plt.figure()
plt.imshow(gmask_high,cmap='gray')
plt.title("inverted Gaussian filter")
plt.show()


# high_passed = np.abs(ftimage *gmask_high )


# high_passed = ndimage.convolve(ftimage_magspec, np.array([[-1, -1, -1], [-1, 8, -1], [-1, -1, -1]]))

high_passed = ndimage.sobel(ftimage_magspec)

# plt.figure()
# plt.imshow(ftimage, cmap='gray')
# plt.title("ftimage")

plt.figure()
plt.imshow(high_passed, cmap='gray')
plt.title("high passed")

plt.figure()
plt.imshow(np.log(ftimage_magspec), cmap='gray')
plt.title("ftimage_magspec")


f_ishift = np.fft.ifftshift(high_passed)
img_back2 = np.fft.ifft2(f_ishift)
img_back2 = np.abs(img_back2)



# plt.figure()
# plt.imshow(ftimage)

plt.figure()
plt.imshow(img_back2, cmap='gray')
plt.title("Convolved and reconstructed Ftt")

img_back3 = img - img_back
plt.figure()
plt.imshow(img_back3, cmap='gray')

f3 = np.fft.fft2(img_back3)
fshift3 = np.fft.fftshift(f3)
magnitude_spectrum3 = 30*np.log(np.abs(fshift3))

plt.figure()
plt.imshow(magnitude_spectrum3, cmap='gray')
